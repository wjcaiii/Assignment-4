# %% [markdown]
# # Web Scraping

# %% [markdown]
# First, we need to import requests and BeautifulSoup for web scraping.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# We need to enter the website from which we're about to extract information, and use html_string with BeautifulSoup.

# %%
response = requests.get("https://genius.com/albums/Adele/25-target-exclusive")
html_string = response.text
document = BeautifulSoup(html_string, "html.parser")

# %% [markdown]
# Then, we need to find the titles of the songs with the find_all() function.

# %%
song_title_tags = document.find_all("h3")
song_title_tags
# Out:
# [<h3 class="chart_row-content-title">
#                Hello
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="chart_row-content-title">
#                Send My Love (To Your New Lover)
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="chart_row-content-title">
#                I Miss You
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="chart_row-content-title">
#                When We Were Young
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="chart_row-content-title">
#                Remedy
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="chart_row-content-title">
#                Water Under the Bridge
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="chart_row-content-title">
#                River Lea
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="chart_row-content-title">
#                Love in the Dark
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="chart_row-content-title">
#                Million Years Ago
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="chart_row-content-title">
#                All I Ask
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="chart_row-content-title">
#                Sweetest Devotion
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="chart_row-content-title">
#                Can't Let Go
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="chart_row-content-title">
#                Lay Me Down
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="chart_row-content-title">
#                Why Do You Love Me
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>,
#  <h3 class="annotation_label">Translations</h3>,
#  <h3>30</h3>,
#  <h3>30 (Target Exclusive)</h3>]

# %% [markdown]
# If we want only the text contained between those tags, we can use .text to extract just the text.

# %%
titles_list = [song.text for song in song_title_tags]
titles_list
# Out:
# ['\n              Hello\n              Lyrics\n',
#  '\n              Send My Love (To Your New Lover)\n              Lyrics\n',
#  '\n              I Miss You\n              Lyrics\n',
#  '\n              When We Were Young\n              Lyrics\n',
#  '\n              Remedy\n              Lyrics\n',
#  '\n              Water Under the Bridge\n              Lyrics\n',
#  '\n              River Lea\n              Lyrics\n',
#  '\n              Love in the Dark\n              Lyrics\n',
#  '\n              Million Years Ago\n              Lyrics\n',
#  '\n              All I Ask\n              Lyrics\n',
#  '\n              Sweetest Devotion\n              Lyrics\n',
#  "\n              Can't Let Go\n              Lyrics\n",
#  '\n              Lay Me Down\n              Lyrics\n',
#  '\n              Why Do You Love Me\n              Lyrics\n',
#  'Translations',
#  '30',
#  '30 (Target Exclusive)']

# %% [markdown]
# Next, we filter out the useless information and only leave the titles in the list. The useless information is different from the titles, so we can use startswith() function.

# %%
raw_title=[item for item in titles_list if item.startswith('\n')]
raw_title
# Out:
# ['\n              Hello\n              Lyrics\n',
#  '\n              Send My Love (To Your New Lover)\n              Lyrics\n',
#  '\n              I Miss You\n              Lyrics\n',
#  '\n              When We Were Young\n              Lyrics\n',
#  '\n              Remedy\n              Lyrics\n',
#  '\n              Water Under the Bridge\n              Lyrics\n',
#  '\n              River Lea\n              Lyrics\n',
#  '\n              Love in the Dark\n              Lyrics\n',
#  '\n              Million Years Ago\n              Lyrics\n',
#  '\n              All I Ask\n              Lyrics\n',
#  '\n              Sweetest Devotion\n              Lyrics\n',
#  "\n              Can't Let Go\n              Lyrics\n",
#  '\n              Lay Me Down\n              Lyrics\n',
#  '\n              Why Do You Love Me\n              Lyrics\n']

# %% [markdown]
# The titles left still need to be cleaned with replace() function (filter out the term "Lyrics") and strip() function (remove spaces).

# %%
song_titles=[item.replace('Lyrics', '').strip() for item in raw_title]
song_titles
# Out:
# ['Hello',
#  'Send My Love (To Your New Lover)',
#  'I Miss You',
#  'When We Were Young',
#  'Remedy',
#  'Water Under the Bridge',
#  'River Lea',
#  'Love in the Dark',
#  'Million Years Ago',
#  'All I Ask',
#  'Sweetest Devotion',
#  "Can't Let Go",
#  'Lay Me Down',
#  'Why Do You Love Me']

# %% [markdown]
# Now, we get a list of titles. Then, we need to extract the corresponding link of each song. The process is similar to that above. We find the location of the links first.

# %%
links = document.find_all("div", class_="chart_row-content")
links
# Out:
# [<div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-hello-lyrics">
#  <h3 class="chart_row-content-title">
#                Hello
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>,
#  <div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-send-my-love-to-your-new-lover-lyrics">
#  <h3 class="chart_row-content-title">
#                Send My Love (To Your New Lover)
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>,
#  <div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-i-miss-you-lyrics">
#  <h3 class="chart_row-content-title">
#                I Miss You
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>,
#  <div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-when-we-were-young-lyrics">
#  <h3 class="chart_row-content-title">
#                When We Were Young
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>,
#  <div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-remedy-lyrics">
#  <h3 class="chart_row-content-title">
#                Remedy
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>,
#  <div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-water-under-the-bridge-lyrics">
#  <h3 class="chart_row-content-title">
#                Water Under the Bridge
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>,
#  <div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-river-lea-lyrics">
#  <h3 class="chart_row-content-title">
#                River Lea
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>,
#  <div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-love-in-the-dark-lyrics">
#  <h3 class="chart_row-content-title">
#                Love in the Dark
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>,
#  <div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-million-years-ago-lyrics">
#  <h3 class="chart_row-content-title">
#                Million Years Ago
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>,
#  <div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-all-i-ask-lyrics">
#  <h3 class="chart_row-content-title">
#                All I Ask
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>,
#  <div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-sweetest-devotion-lyrics">
#  <h3 class="chart_row-content-title">
#                Sweetest Devotion
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>,
#  <div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-cant-let-go-lyrics">
#  <h3 class="chart_row-content-title">
#                Can't Let Go
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>,
#  <div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-lay-me-down-lyrics">
#  <h3 class="chart_row-content-title">
#                Lay Me Down
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>,
#  <div class="chart_row-content">
#  <a class="u-display_block" href="https://genius.com/Adele-why-do-you-love-me-lyrics">
#  <h3 class="chart_row-content-title">
#                Why Do You Love Me
#                <span class="chart_row-content-title-subtitle">Lyrics</span>
#  </h3>
#  </a>
#  </div>]

# %% [markdown]
# We extract the links and append them to a new list.

# %%
song_links=[link.find('a', class_="u-display_block")['href'] for link in links]
song_links
# Out:
# ['https://genius.com/Adele-hello-lyrics',
#  'https://genius.com/Adele-send-my-love-to-your-new-lover-lyrics',
#  'https://genius.com/Adele-i-miss-you-lyrics',
#  'https://genius.com/Adele-when-we-were-young-lyrics',
#  'https://genius.com/Adele-remedy-lyrics',
#  'https://genius.com/Adele-water-under-the-bridge-lyrics',
#  'https://genius.com/Adele-river-lea-lyrics',
#  'https://genius.com/Adele-love-in-the-dark-lyrics',
#  'https://genius.com/Adele-million-years-ago-lyrics',
#  'https://genius.com/Adele-all-i-ask-lyrics',
#  'https://genius.com/Adele-sweetest-devotion-lyrics',
#  'https://genius.com/Adele-cant-let-go-lyrics',
#  'https://genius.com/Adele-lay-me-down-lyrics',
#  'https://genius.com/Adele-why-do-you-love-me-lyrics']

# %% [markdown]
# Now we have two lists and we can get a Dataframe with these two lists.

# %%
import pandas as pd
songs_df1=pd.DataFrame({'Filename':song_titles, 'Link':song_links})
songs_df1
# Out:
#                             Filename  \
# 0                              Hello
# 1   Send My Love (To Your New Lover)
# 2                         I Miss You
# 3                 When We Were Young
# 4                             Remedy
# 5             Water Under the Bridge
# 6                          River Lea
# 7                   Love in the Dark
# 8                  Million Years Ago
# 9                          All I Ask
# 10                 Sweetest Devotion
# 11                      Can't Let Go
# 12                       Lay Me Down
# 13                Why Do You Love Me
#
#                                                  Link
# 0               https://genius.com/Adele-hello-lyrics
# 1   https://genius.com/Adele-send-my-love-to-your-...
# 2          https://genius.com/Adele-i-miss-you-lyrics
# 3   https://genius.com/Adele-when-we-were-young-ly...
# 4              https://genius.com/Adele-remedy-lyrics
# 5   https://genius.com/Adele-water-under-the-bridg...
# 6           https://genius.com/Adele-river-lea-lyrics
# 7    https://genius.com/Adele-love-in-the-dark-lyrics
# 8   https://genius.com/Adele-million-years-ago-lyrics
# 9           https://genius.com/Adele-all-i-ask-lyrics
# 10  https://genius.com/Adele-sweetest-devotion-lyrics
# 11        https://genius.com/Adele-cant-let-go-lyrics
# 12        https://genius.com/Adele-lay-me-down-lyrics
# 13  https://genius.com/Adele-why-do-you-love-me-ly...

# %% [markdown]
# I was about to collect the lyrics with these links, add them to the data frame, and separate the lyrics into different text files. However, the HTML text of the lyrics was too complicated to comprehend (It looks quite different from the HTML text above. Maybe it's javascript.). Therefore, I had to give up and extract the scripts manually.

# %% [markdown]
# Now that I failed in extracting lyrics, I intended to continue with preprocessing and annotating my text files and merge the generated Dataframe and  songs_df1 into a new Dataframe at last.

# %% [markdown]
# # Installing, Importing and Preprocessing

# %%
# Install and import spacy and plotly.
# !pip install spaCy
# !pip install plotly
# !pip install nbformat==5.1.2
# Out:
# Requirement already satisfied: spaCy in c:\users\14359\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (2.5.2)
# Requirement already satisfied: jinja2 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\14359\anaconda3\lib\site-packages (from spaCy) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\14359\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spaCy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in c:\users\14359\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spaCy) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\14359\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spaCy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\14359\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spaCy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\14359\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spaCy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\14359\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spaCy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\14359\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spaCy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\14359\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spaCy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\14359\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spaCy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\14359\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spaCy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\14359\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spaCy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\14359\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spaCy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\14359\anaconda3\lib\site-packages (from jinja2->spaCy) (2.1.1)
# Requirement already satisfied: plotly in c:\users\14359\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\14359\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: nbformat==5.1.2 in c:\users\14359\anaconda3\lib\site-packages (5.1.2)
# Requirement already satisfied: ipython-genutils in c:\users\14359\anaconda3\lib\site-packages (from nbformat==5.1.2) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in c:\users\14359\anaconda3\lib\site-packages (from nbformat==5.1.2) (5.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\14359\anaconda3\lib\site-packages (from nbformat==5.1.2) (4.20.0)
# Requirement already satisfied: jupyter-core in c:\users\14359\anaconda3\lib\site-packages (from nbformat==5.1.2) (5.3.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\14359\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==5.1.2) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\14359\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==5.1.2) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\14359\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==5.1.2) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\14359\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==5.1.2) (0.13.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\14359\anaconda3\lib\site-packages (from jupyter-core->nbformat==5.1.2) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\14359\anaconda3\lib\site-packages (from jupyter-core->nbformat==5.1.2) (305.1)

# %%
# Import spacy
import spacy

# Install English language model
# !spacy download en_core_web_sm

# Import os to upload documents and metadata
import os

# Load spaCy visualizer
from spacy import displacy

# Import pandas DataFrame packages
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# Import graphing package
import plotly.graph_objects as go
import plotly.express as px
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.4/12.8 MB 8.5 MB/s eta 0:00:02
#      -- ------------------------------------- 0.9/12.8 MB 11.4 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.4/12.8 MB 11.1 MB/s eta 0:00:02
#      ------ --------------------------------- 1.9/12.8 MB 11.3 MB/s eta 0:00:01
#      ------- -------------------------------- 2.4/12.8 MB 10.8 MB/s eta 0:00:01
#      -------- ------------------------------- 2.8/12.8 MB 11.1 MB/s eta 0:00:01
#      ---------- ----------------------------- 3.3/12.8 MB 10.9 MB/s eta 0:00:01
#      ----------- ---------------------------- 3.7/12.8 MB 11.2 MB/s eta 0:00:01
#      ------------ --------------------------- 4.1/12.8 MB 11.0 MB/s eta 0:00:01
#      -------------- ------------------------- 4.5/12.8 MB 11.1 MB/s eta 0:00:01
#      --------------- ------------------------ 5.0/12.8 MB 11.1 MB/s eta 0:00:01
#      ----------------- ---------------------- 5.6/12.8 MB 11.2 MB/s eta 0:00:01
#      ------------------- -------------------- 6.1/12.8 MB 11.2 MB/s eta 0:00:01
#      -------------------- ------------------- 6.7/12.8 MB 11.2 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.2/12.8 MB 11.2 MB/s eta 0:00:01
#      ------------------------ --------------- 7.7/12.8 MB 11.2 MB/s eta 0:00:01
#      ------------------------- -------------- 8.1/12.8 MB 11.3 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.8 MB 11.3 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.1/12.8 MB 11.1 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.5/12.8 MB 11.1 MB/s eta 0:00:01
#      ------------------------------ -------- 10.1/12.8 MB 11.1 MB/s eta 0:00:01
#      -------------------------------- ------ 10.6/12.8 MB 11.1 MB/s eta 0:00:01
#      --------------------------------- ----- 11.1/12.8 MB 11.1 MB/s eta 0:00:01
#      ----------------------------------- --- 11.7/12.8 MB 11.3 MB/s eta 0:00:01
#      ------------------------------------- - 12.2/12.8 MB 11.3 MB/s eta 0:00:01
#      --------------------------------------  12.7/12.8 MB 11.3 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 11.3 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\14359\anaconda3\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.2)
# Requirement already satisfied: jinja2 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\14359\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\14359\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in c:\users\14359\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\14359\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\14359\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\14359\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\14359\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\14359\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\14359\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\14359\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\14359\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\14359\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\14359\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\14359\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Create empty lists for file names and contents
texts = []
file_names = []

# Iterate through each file in the folder
for _file_name in os.listdir('Adele_Album 25_Songs'):
# Look for only text files
    if _file_name.endswith('.txt'):
    # Append contents of each text file to text list
        texts.append(open('Adele_Album 25_Songs' + '/' + _file_name, 'r', encoding='utf-8').read())
        # Append name of each file to file name list
        file_names.append(_file_name)
file_names
# Out:
# ['All I Ask.txt',
#  "Can't Let Go.txt",
#  'Hello.txt',
#  'I Miss You.txt',
#  'Lay Me Down.txt',
#  'Love in the Dark.txt',
#  'Million Years Ago.txt',
#  'Remedy.txt',
#  'River Lea.txt',
#  'Send My Love (To Your New Lover).txt',
#  'Sweetest Devotion.txt',
#  'Water Under the Bridge.txt',
#  'When We Were Young.txt',
#  'Why Do You Love Me.txt']

# %%
# Create a dataframe associating each file name with its text
text_df = pd.DataFrame({'Filename':file_names,'Document':texts})
text_df
# Out:
#                                 Filename  \
# 0                          All I Ask.txt
# 1                       Can't Let Go.txt
# 2                              Hello.txt
# 3                         I Miss You.txt
# 4                        Lay Me Down.txt
# 5                   Love in the Dark.txt
# 6                  Million Years Ago.txt
# 7                             Remedy.txt
# 8                          River Lea.txt
# 9   Send My Love (To Your New Lover).txt
# 10                 Sweetest Devotion.txt
# 11            Water Under the Bridge.txt
# 12                When We Were Young.txt
# 13                Why Do You Love Me.txt
#
#                                              Document
# 0   I will leave my heart at the door\nI won't say...
# 1   When did it go wrong? I will never know\nI hav...
# 2   Hello, it's me\nI was wondering if, after all ...
# 3   I want every single piece of you\nI want your ...
# 4   I would never lie to you unless you tell me to...
# 5   Take your eyes off of me so I can leave\nI'm f...
# 6   \nI only wanted to have fun\nLearning to fly, ...
# 7   I remember all of the things that I thought I ...
# 8   Everybody tells me it's 'bout time that I move...
# 9   This was all you, none of it me\nYou put your ...
# 10  With your loving, there ain't nothing that I c...
# 11  If you're not the one for me\nThen how come I ...
# 12  Everybody loves the things you do\nFrom the wa...
# 13  Why do you love me?\nThere must be something i...

# %%
# Remove extra spaces from documents
text_df['Text'] = text_df['Document'].str.replace('\s+', ' ', regex=True).str.strip()
text_df
# Out:
#                                 Filename  \
# 0                          All I Ask.txt
# 1                       Can't Let Go.txt
# 2                              Hello.txt
# 3                         I Miss You.txt
# 4                        Lay Me Down.txt
# 5                   Love in the Dark.txt
# 6                  Million Years Ago.txt
# 7                             Remedy.txt
# 8                          River Lea.txt
# 9   Send My Love (To Your New Lover).txt
# 10                 Sweetest Devotion.txt
# 11            Water Under the Bridge.txt
# 12                When We Were Young.txt
# 13                Why Do You Love Me.txt
#
#                                              Document  \
# 0   I will leave my heart at the door\nI won't say...
# 1   When did it go wrong? I will never know\nI hav...
# 2   Hello, it's me\nI was wondering if, after all ...
# 3   I want every single piece of you\nI want your ...
# 4   I would never lie to you unless you tell me to...
# 5   Take your eyes off of me so I can leave\nI'm f...
# 6   \nI only wanted to have fun\nLearning to fly, ...
# 7   I remember all of the things that I thought I ...
# 8   Everybody tells me it's 'bout time that I move...
# 9   This was all you, none of it me\nYou put your ...
# 10  With your loving, there ain't nothing that I c...
# 11  If you're not the one for me\nThen how come I ...
# 12  Everybody loves the things you do\nFrom the wa...
# 13  Why do you love me?\nThere must be something i...
#
#                                                  Text
# 0   I will leave my heart at the door I won't say ...
# 1   When did it go wrong? I will never know I have...
# 2   Hello, it's me I was wondering if, after all t...
# 3   I want every single piece of you I want your h...
# 4   I would never lie to you unless you tell me to...
# 5   Take your eyes off of me so I can leave I'm fa...
# 6   I only wanted to have fun Learning to fly, lea...
# 7   I remember all of the things that I thought I ...
# 8   Everybody tells me it's 'bout time that I move...
# 9   This was all you, none of it me You put your h...
# 10  With your loving, there ain't nothing that I c...
# 11  If you're not the one for me Then how come I c...
# 12  Everybody loves the things you do From the way...
# 13  Why do you love me? There must be something in...

# %% [markdown]
# Now we can merge the metadata and text_df into a new Dataframe.

# %%
# Load metadata.
metadata_df = pd.read_csv('C:/Users/14359/Desktop/metadata.csv')

# Remove .txt from title of each paper
text_df['Filename'] = text_df['Filename'].str.replace('.txt', '', regex=True)

# Rename column from Title to Filename
metadata_df.rename(columns={"Title": "Filename"}, inplace=True)

# Merge metadata and papers into new DataFrame
# Will only keep rows where both essay and metadata are present
songs_df2 = metadata_df.merge(text_df,on='Filename')
songs_df2
# Out:
#                             Filename  Track                Producer  \
# 0                              Hello      1            Greg Kurstin
# 1   Send My Love (To Your New Lover)      2  Shellback & Max Martin
# 2                         I Miss You      3            Paul Epworth
# 3                 When We Were Young      4        Ariel Rechtshaid
# 4                             Remedy      5             Ryan Tedder
# 5             Water Under the Bridge      6            Greg Kurstin
# 6                          River Lea      7            Danger Mouse
# 7                   Love in the Dark      8            Samuel Dixon
# 8                  Million Years Ago      9            Greg Kurstin
# 9                          All I Ask     10        The Smeezingtons
# 10                 Sweetest Devotion     11            Paul Epworth
# 11                      Can't Let Go     12             Linda Perry
# 12                       Lay Me Down     13             Mark Ronson
# 13                Why Do You Love Me     14        Ariel Rechtshaid
#
#                                              Document  \
# 0   Hello, it's me\nI was wondering if, after all ...
# 1   This was all you, none of it me\nYou put your ...
# 2   I want every single piece of you\nI want your ...
# 3   Everybody loves the things you do\nFrom the wa...
# 4   I remember all of the things that I thought I ...
# 5   If you're not the one for me\nThen how come I ...
# 6   Everybody tells me it's 'bout time that I move...
# 7   Take your eyes off of me so I can leave\nI'm f...
# 8   \nI only wanted to have fun\nLearning to fly, ...
# 9   I will leave my heart at the door\nI won't say...
# 10  With your loving, there ain't nothing that I c...
# 11  When did it go wrong? I will never know\nI hav...
# 12  I would never lie to you unless you tell me to...
# 13  Why do you love me?\nThere must be something i...
#
#                                                  Text
# 0   Hello, it's me I was wondering if, after all t...
# 1   This was all you, none of it me You put your h...
# 2   I want every single piece of you I want your h...
# 3   Everybody loves the things you do From the way...
# 4   I remember all of the things that I thought I ...
# 5   If you're not the one for me Then how come I c...
# 6   Everybody tells me it's 'bout time that I move...
# 7   Take your eyes off of me so I can leave I'm fa...
# 8   I only wanted to have fun Learning to fly, lea...
# 9   I will leave my heart at the door I won't say ...
# 10  With your loving, there ain't nothing that I c...
# 11  When did it go wrong? I will never know I have...
# 12  I would never lie to you unless you tell me to...
# 13  Why do you love me? There must be something in...

# %% [markdown]
# # Text Enrichment with spaCy

# %% [markdown]
# The lyrics are clean. Therefore, we continue to produce the columns of tokens, lemmas, and parts of speech. First, we need to load nlp pipelines.

# %%
# Load nlp pipeline
nlp = spacy.load('en_core_web_sm')

# Check what functions it performs
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
# Define a function that runs the nlp pipeline on any given input text
def process_text(text):
    return nlp(text)

# %% [markdown]
# Now we can apply the function to the Document column and restore the result in a new column called Doc. Based on Doc, we can get tokens, lemmas, and parts of speech by using different functions.

# %%
# Apply the function to the "Document" column, so that the nlp pipeline is called on each song
songs_df2['Doc'] = songs_df2['Text'].apply(process_text)
songs_df2
# Out:
#                             Filename  Track                Producer  \
# 0                              Hello      1            Greg Kurstin
# 1   Send My Love (To Your New Lover)      2  Shellback & Max Martin
# 2                         I Miss You      3            Paul Epworth
# 3                 When We Were Young      4        Ariel Rechtshaid
# 4                             Remedy      5             Ryan Tedder
# 5             Water Under the Bridge      6            Greg Kurstin
# 6                          River Lea      7            Danger Mouse
# 7                   Love in the Dark      8            Samuel Dixon
# 8                  Million Years Ago      9            Greg Kurstin
# 9                          All I Ask     10        The Smeezingtons
# 10                 Sweetest Devotion     11            Paul Epworth
# 11                      Can't Let Go     12             Linda Perry
# 12                       Lay Me Down     13             Mark Ronson
# 13                Why Do You Love Me     14        Ariel Rechtshaid
#
#                                              Document  \
# 0   Hello, it's me\nI was wondering if, after all ...
# 1   This was all you, none of it me\nYou put your ...
# 2   I want every single piece of you\nI want your ...
# 3   Everybody loves the things you do\nFrom the wa...
# 4   I remember all of the things that I thought I ...
# 5   If you're not the one for me\nThen how come I ...
# 6   Everybody tells me it's 'bout time that I move...
# 7   Take your eyes off of me so I can leave\nI'm f...
# 8   \nI only wanted to have fun\nLearning to fly, ...
# 9   I will leave my heart at the door\nI won't say...
# 10  With your loving, there ain't nothing that I c...
# 11  When did it go wrong? I will never know\nI hav...
# 12  I would never lie to you unless you tell me to...
# 13  Why do you love me?\nThere must be something i...
#
#                                                  Text  \
# 0   Hello, it's me I was wondering if, after all t...
# 1   This was all you, none of it me You put your h...
# 2   I want every single piece of you I want your h...
# 3   Everybody loves the things you do From the way...
# 4   I remember all of the things that I thought I ...
# 5   If you're not the one for me Then how come I c...
# 6   Everybody tells me it's 'bout time that I move...
# 7   Take your eyes off of me so I can leave I'm fa...
# 8   I only wanted to have fun Learning to fly, lea...
# 9   I will leave my heart at the door I won't say ...
# 10  With your loving, there ain't nothing that I c...
# 11  When did it go wrong? I will never know I have...
# 12  I would never lie to you unless you tell me to...
# 13  Why do you love me? There must be something in...
#
#                                                   Doc
# 0   (Hello, ,, it, 's, me, I, was, wondering, if, ...
# 1   (This, was, all, you, ,, none, of, it, me, You...
# 2   (I, want, every, single, piece, of, you, I, wa...
# 3   (Everybody, loves, the, things, you, do, From,...
# 4   (I, remember, all, of, the, things, that, I, t...
# 5   (If, you, 're, not, the, one, for, me, Then, h...
# 6   (Everybody, tells, me, it, 's, 'bout, time, th...
# 7   (Take, your, eyes, off, of, me, so, I, can, le...
# 8   (I, only, wanted, to, have, fun, Learning, to,...
# 9   (I, will, leave, my, heart, at, the, door, I, ...
# 10  (With, your, loving, ,, there, ai, n't, nothin...
# 11  (When, did, it, go, wrong, ?, I, will, never, ...
# 12  (I, would, never, lie, to, you, unless, you, t...
# 13  (Why, do, you, love, me, ?, There, must, be, s...

# %% [markdown]
# Based on Doc, we can get tokens, lemmas, and parts of speech by using different functions.

# %% [markdown]
# #### Tokenization

# %%
# Define a function to retrieve tokens from a Doc object
def get_token(doc):
    return [(token.text) for token in doc]
    
# Run the token retrieval function on the doc objects in the dataframe
songs_df2['Tokens'] = songs_df2['Doc'].apply(get_token)
songs_df2
# Out:
#                             Filename  Track                Producer  \
# 0                              Hello      1            Greg Kurstin
# 1   Send My Love (To Your New Lover)      2  Shellback & Max Martin
# 2                         I Miss You      3            Paul Epworth
# 3                 When We Were Young      4        Ariel Rechtshaid
# 4                             Remedy      5             Ryan Tedder
# 5             Water Under the Bridge      6            Greg Kurstin
# 6                          River Lea      7            Danger Mouse
# 7                   Love in the Dark      8            Samuel Dixon
# 8                  Million Years Ago      9            Greg Kurstin
# 9                          All I Ask     10        The Smeezingtons
# 10                 Sweetest Devotion     11            Paul Epworth
# 11                      Can't Let Go     12             Linda Perry
# 12                       Lay Me Down     13             Mark Ronson
# 13                Why Do You Love Me     14        Ariel Rechtshaid
#
#                                              Document  \
# 0   Hello, it's me\nI was wondering if, after all ...
# 1   This was all you, none of it me\nYou put your ...
# 2   I want every single piece of you\nI want your ...
# 3   Everybody loves the things you do\nFrom the wa...
# 4   I remember all of the things that I thought I ...
# 5   If you're not the one for me\nThen how come I ...
# 6   Everybody tells me it's 'bout time that I move...
# 7   Take your eyes off of me so I can leave\nI'm f...
# 8   \nI only wanted to have fun\nLearning to fly, ...
# 9   I will leave my heart at the door\nI won't say...
# 10  With your loving, there ain't nothing that I c...
# 11  When did it go wrong? I will never know\nI hav...
# 12  I would never lie to you unless you tell me to...
# 13  Why do you love me?\nThere must be something i...
#
#                                                  Text  \
# 0   Hello, it's me I was wondering if, after all t...
# 1   This was all you, none of it me You put your h...
# 2   I want every single piece of you I want your h...
# 3   Everybody loves the things you do From the way...
# 4   I remember all of the things that I thought I ...
# 5   If you're not the one for me Then how come I c...
# 6   Everybody tells me it's 'bout time that I move...
# 7   Take your eyes off of me so I can leave I'm fa...
# 8   I only wanted to have fun Learning to fly, lea...
# 9   I will leave my heart at the door I won't say ...
# 10  With your loving, there ain't nothing that I c...
# 11  When did it go wrong? I will never know I have...
# 12  I would never lie to you unless you tell me to...
# 13  Why do you love me? There must be something in...
#
#                                                   Doc  \
# 0   (Hello, ,, it, 's, me, I, was, wondering, if, ...
# 1   (This, was, all, you, ,, none, of, it, me, You...
# 2   (I, want, every, single, piece, of, you, I, wa...
# 3   (Everybody, loves, the, things, you, do, From,...
# 4   (I, remember, all, of, the, things, that, I, t...
# 5   (If, you, 're, not, the, one, for, me, Then, h...
# 6   (Everybody, tells, me, it, 's, 'bout, time, th...
# 7   (Take, your, eyes, off, of, me, so, I, can, le...
# 8   (I, only, wanted, to, have, fun, Learning, to,...
# 9   (I, will, leave, my, heart, at, the, door, I, ...
# 10  (With, your, loving, ,, there, ai, n't, nothin...
# 11  (When, did, it, go, wrong, ?, I, will, never, ...
# 12  (I, would, never, lie, to, you, unless, you, t...
# 13  (Why, do, you, love, me, ?, There, must, be, s...
#
#                                                Tokens
# 0   [Hello, ,, it, 's, me, I, was, wondering, if, ...
# 1   [This, was, all, you, ,, none, of, it, me, You...
# 2   [I, want, every, single, piece, of, you, I, wa...
# 3   [Everybody, loves, the, things, you, do, From,...
# 4   [I, remember, all, of, the, things, that, I, t...
# 5   [If, you, 're, not, the, one, for, me, Then, h...
# 6   [Everybody, tells, me, it, 's, 'bout, time, th...
# 7   [Take, your, eyes, off, of, me, so, I, can, le...
# 8   [I, only, wanted, to, have, fun, Learning, to,...
# 9   [I, will, leave, my, heart, at, the, door, I, ...
# 10  [With, your, loving, ,, there, ai, n't, nothin...
# 11  [When, did, it, go, wrong, ?, I, will, never, ...
# 12  [I, would, never, lie, to, you, unless, you, t...
# 13  [Why, do, you, love, me, ?, There, must, be, s...

# %% [markdown]
# #### Lemmatization

# %%
# Define a function to retrieve lemmas from a doc object
def get_lemma(doc):
    return [(token.lemma_) for token in doc]

# Run the lemma retrieval function on the doc objects in the dataframe
songs_df2['Lemmas'] = songs_df2['Doc'].apply(get_lemma)
songs_df2
# Out:
#                             Filename  Track                Producer  \
# 0                              Hello      1            Greg Kurstin
# 1   Send My Love (To Your New Lover)      2  Shellback & Max Martin
# 2                         I Miss You      3            Paul Epworth
# 3                 When We Were Young      4        Ariel Rechtshaid
# 4                             Remedy      5             Ryan Tedder
# 5             Water Under the Bridge      6            Greg Kurstin
# 6                          River Lea      7            Danger Mouse
# 7                   Love in the Dark      8            Samuel Dixon
# 8                  Million Years Ago      9            Greg Kurstin
# 9                          All I Ask     10        The Smeezingtons
# 10                 Sweetest Devotion     11            Paul Epworth
# 11                      Can't Let Go     12             Linda Perry
# 12                       Lay Me Down     13             Mark Ronson
# 13                Why Do You Love Me     14        Ariel Rechtshaid
#
#                                              Document  \
# 0   Hello, it's me\nI was wondering if, after all ...
# 1   This was all you, none of it me\nYou put your ...
# 2   I want every single piece of you\nI want your ...
# 3   Everybody loves the things you do\nFrom the wa...
# 4   I remember all of the things that I thought I ...
# 5   If you're not the one for me\nThen how come I ...
# 6   Everybody tells me it's 'bout time that I move...
# 7   Take your eyes off of me so I can leave\nI'm f...
# 8   \nI only wanted to have fun\nLearning to fly, ...
# 9   I will leave my heart at the door\nI won't say...
# 10  With your loving, there ain't nothing that I c...
# 11  When did it go wrong? I will never know\nI hav...
# 12  I would never lie to you unless you tell me to...
# 13  Why do you love me?\nThere must be something i...
#
#                                                  Text  \
# 0   Hello, it's me I was wondering if, after all t...
# 1   This was all you, none of it me You put your h...
# 2   I want every single piece of you I want your h...
# 3   Everybody loves the things you do From the way...
# 4   I remember all of the things that I thought I ...
# 5   If you're not the one for me Then how come I c...
# 6   Everybody tells me it's 'bout time that I move...
# 7   Take your eyes off of me so I can leave I'm fa...
# 8   I only wanted to have fun Learning to fly, lea...
# 9   I will leave my heart at the door I won't say ...
# 10  With your loving, there ain't nothing that I c...
# 11  When did it go wrong? I will never know I have...
# 12  I would never lie to you unless you tell me to...
# 13  Why do you love me? There must be something in...
#
#                                                   Doc  \
# 0   (Hello, ,, it, 's, me, I, was, wondering, if, ...
# 1   (This, was, all, you, ,, none, of, it, me, You...
# 2   (I, want, every, single, piece, of, you, I, wa...
# 3   (Everybody, loves, the, things, you, do, From,...
# 4   (I, remember, all, of, the, things, that, I, t...
# 5   (If, you, 're, not, the, one, for, me, Then, h...
# 6   (Everybody, tells, me, it, 's, 'bout, time, th...
# 7   (Take, your, eyes, off, of, me, so, I, can, le...
# 8   (I, only, wanted, to, have, fun, Learning, to,...
# 9   (I, will, leave, my, heart, at, the, door, I, ...
# 10  (With, your, loving, ,, there, ai, n't, nothin...
# 11  (When, did, it, go, wrong, ?, I, will, never, ...
# 12  (I, would, never, lie, to, you, unless, you, t...
# 13  (Why, do, you, love, me, ?, There, must, be, s...
#
#                                                Tokens  \
# 0   [Hello, ,, it, 's, me, I, was, wondering, if, ...
# 1   [This, was, all, you, ,, none, of, it, me, You...
# 2   [I, want, every, single, piece, of, you, I, wa...
# 3   [Everybody, loves, the, things, you, do, From,...
# 4   [I, remember, all, of, the, things, that, I, t...
# 5   [If, you, 're, not, the, one, for, me, Then, h...
# 6   [Everybody, tells, me, it, 's, 'bout, time, th...
# 7   [Take, your, eyes, off, of, me, so, I, can, le...
# 8   [I, only, wanted, to, have, fun, Learning, to,...
# 9   [I, will, leave, my, heart, at, the, door, I, ...
# 10  [With, your, loving, ,, there, ai, n't, nothin...
# 11  [When, did, it, go, wrong, ?, I, will, never, ...
# 12  [I, would, never, lie, to, you, unless, you, t...
# 13  [Why, do, you, love, me, ?, There, must, be, s...
#
#                                                Lemmas
# 0   [hello, ,, it, be, I, I, be, wonder, if, ,, af...
# 1   [this, be, all, you, ,, none, of, it, I, you, ...
# 2   [I, want, every, single, piece, of, you, I, wa...
# 3   [everybody, love, the, thing, you, do, from, t...
# 4   [I, remember, all, of, the, thing, that, I, th...
# 5   [if, you, be, not, the, one, for, I, then, how...
# 6   [everybody, tell, I, it, be, 'bout, time, that...
# 7   [take, your, eye, off, of, I, so, I, can, leav...
# 8   [I, only, want, to, have, fun, Learning, to, f...
# 9   [I, will, leave, my, heart, at, the, door, I, ...
# 10  [with, your, loving, ,, there, be, not, nothin...
# 11  [when, do, it, go, wrong, ?, I, will, never, k...
# 12  [I, would, never, lie, to, you, unless, you, t...
# 13  [why, do, you, love, I, ?, there, must, be, so...

# %% [markdown]
# #### Part of Speech Tagging

# %%
# Define a function to retrieve parts of speech from a doc object
def get_pos(doc):
    #Return the coarse- and fine-grained part of speech text for each token in the doc
    return [(token.pos_, token.tag_) for token in doc]

songs_df2['POS'] = songs_df2['Doc'].apply(get_pos)
songs_df2
# Out:
#                             Filename  Track                Producer  \
# 0                              Hello      1            Greg Kurstin
# 1   Send My Love (To Your New Lover)      2  Shellback & Max Martin
# 2                         I Miss You      3            Paul Epworth
# 3                 When We Were Young      4        Ariel Rechtshaid
# 4                             Remedy      5             Ryan Tedder
# 5             Water Under the Bridge      6            Greg Kurstin
# 6                          River Lea      7            Danger Mouse
# 7                   Love in the Dark      8            Samuel Dixon
# 8                  Million Years Ago      9            Greg Kurstin
# 9                          All I Ask     10        The Smeezingtons
# 10                 Sweetest Devotion     11            Paul Epworth
# 11                      Can't Let Go     12             Linda Perry
# 12                       Lay Me Down     13             Mark Ronson
# 13                Why Do You Love Me     14        Ariel Rechtshaid
#
#                                              Document  \
# 0   Hello, it's me\nI was wondering if, after all ...
# 1   This was all you, none of it me\nYou put your ...
# 2   I want every single piece of you\nI want your ...
# 3   Everybody loves the things you do\nFrom the wa...
# 4   I remember all of the things that I thought I ...
# 5   If you're not the one for me\nThen how come I ...
# 6   Everybody tells me it's 'bout time that I move...
# 7   Take your eyes off of me so I can leave\nI'm f...
# 8   \nI only wanted to have fun\nLearning to fly, ...
# 9   I will leave my heart at the door\nI won't say...
# 10  With your loving, there ain't nothing that I c...
# 11  When did it go wrong? I will never know\nI hav...
# 12  I would never lie to you unless you tell me to...
# 13  Why do you love me?\nThere must be something i...
#
#                                                  Text  \
# 0   Hello, it's me I was wondering if, after all t...
# 1   This was all you, none of it me You put your h...
# 2   I want every single piece of you I want your h...
# 3   Everybody loves the things you do From the way...
# 4   I remember all of the things that I thought I ...
# 5   If you're not the one for me Then how come I c...
# 6   Everybody tells me it's 'bout time that I move...
# 7   Take your eyes off of me so I can leave I'm fa...
# 8   I only wanted to have fun Learning to fly, lea...
# 9   I will leave my heart at the door I won't say ...
# 10  With your loving, there ain't nothing that I c...
# 11  When did it go wrong? I will never know I have...
# 12  I would never lie to you unless you tell me to...
# 13  Why do you love me? There must be something in...
#
#                                                   Doc  \
# 0   (Hello, ,, it, 's, me, I, was, wondering, if, ...
# 1   (This, was, all, you, ,, none, of, it, me, You...
# 2   (I, want, every, single, piece, of, you, I, wa...
# 3   (Everybody, loves, the, things, you, do, From,...
# 4   (I, remember, all, of, the, things, that, I, t...
# 5   (If, you, 're, not, the, one, for, me, Then, h...
# 6   (Everybody, tells, me, it, 's, 'bout, time, th...
# 7   (Take, your, eyes, off, of, me, so, I, can, le...
# 8   (I, only, wanted, to, have, fun, Learning, to,...
# 9   (I, will, leave, my, heart, at, the, door, I, ...
# 10  (With, your, loving, ,, there, ai, n't, nothin...
# 11  (When, did, it, go, wrong, ?, I, will, never, ...
# 12  (I, would, never, lie, to, you, unless, you, t...
# 13  (Why, do, you, love, me, ?, There, must, be, s...
#
#                                                Tokens  \
# 0   [Hello, ,, it, 's, me, I, was, wondering, if, ...
# 1   [This, was, all, you, ,, none, of, it, me, You...
# 2   [I, want, every, single, piece, of, you, I, wa...
# 3   [Everybody, loves, the, things, you, do, From,...
# 4   [I, remember, all, of, the, things, that, I, t...
# 5   [If, you, 're, not, the, one, for, me, Then, h...
# 6   [Everybody, tells, me, it, 's, 'bout, time, th...
# 7   [Take, your, eyes, off, of, me, so, I, can, le...
# 8   [I, only, wanted, to, have, fun, Learning, to,...
# 9   [I, will, leave, my, heart, at, the, door, I, ...
# 10  [With, your, loving, ,, there, ai, n't, nothin...
# 11  [When, did, it, go, wrong, ?, I, will, never, ...
# 12  [I, would, never, lie, to, you, unless, you, t...
# 13  [Why, do, you, love, me, ?, There, must, be, s...
#
#                                                Lemmas  \
# 0   [hello, ,, it, be, I, I, be, wonder, if, ,, af...
# 1   [this, be, all, you, ,, none, of, it, I, you, ...
# 2   [I, want, every, single, piece, of, you, I, wa...
# 3   [everybody, love, the, thing, you, do, from, t...
# 4   [I, remember, all, of, the, thing, that, I, th...
# 5   [if, you, be, not, the, one, for, I, then, how...
# 6   [everybody, tell, I, it, be, 'bout, time, that...
# 7   [take, your, eye, off, of, I, so, I, can, leav...
# 8   [I, only, want, to, have, fun, Learning, to, f...
# 9   [I, will, leave, my, heart, at, the, door, I, ...
# 10  [with, your, loving, ,, there, be, not, nothin...
# 11  [when, do, it, go, wrong, ?, I, will, never, k...
# 12  [I, would, never, lie, to, you, unless, you, t...
# 13  [why, do, you, love, I, ?, there, must, be, so...
#
#                                                   POS
# 0   [(INTJ, UH), (PUNCT, ,), (PRON, PRP), (AUX, VB...
# 1   [(PRON, DT), (AUX, VBD), (PRON, DT), (PRON, PR...
# 2   [(PRON, PRP), (VERB, VBP), (DET, DT), (ADJ, JJ...
# 3   [(PRON, NN), (VERB, VBZ), (DET, DT), (NOUN, NN...
# 4   [(PRON, PRP), (VERB, VBP), (PRON, DT), (ADP, I...
# 5   [(SCONJ, IN), (PRON, PRP), (AUX, VBP), (PART, ...
# 6   [(PRON, NN), (VERB, VBZ), (PRON, PRP), (PRON, ...
# 7   [(VERB, VB), (PRON, PRP$), (NOUN, NNS), (ADP, ...
# 8   [(PRON, PRP), (ADV, RB), (VERB, VBD), (PART, T...
# 9   [(PRON, PRP), (AUX, MD), (VERB, VB), (PRON, PR...
# 10  [(ADP, IN), (PRON, PRP$), (NOUN, NN), (PUNCT, ...
# 11  [(SCONJ, WRB), (AUX, VBD), (PRON, PRP), (VERB,...
# 12  [(PRON, PRP), (AUX, MD), (ADV, RB), (VERB, VB)...
# 13  [(SCONJ, WRB), (AUX, VBP), (PRON, PRP), (VERB,...

# %% [markdown]
# If we don't know what these detailed taggings mean, we can call spacy.explain()

# %%
spacy.explain('UH')
# Out:
# 'interjection'

# %% [markdown]
# #### Named Entity Recognition

# %%
# Define function to extract named entities from doc objects
def extract_named_entities(doc):
    return [ent.label_ for ent in doc.ents]

# Apply function to Doc column and store resulting named entities in new column
songs_df2['Named Entities'] = songs_df2['Doc'].apply(extract_named_entities)
songs_df2['Named Entities']
# Out:
# 0     [GPE, QUANTITY, CARDINAL, CARDINAL, CARDINAL, ...
# 1                                                    []
# 2     [PRODUCT, PRODUCT, PERSON, PRODUCT, PRODUCT, P...
# 3                                           [TIME, GPE]
# 4                                         [WORK_OF_ART]
# 5                            [WORK_OF_ART, WORK_OF_ART]
# 6             [LOC, LOC, DATE, LOC, LOC, LOC, LOC, LOC]
# 7                                            [ORG, ORG]
# 8                              [DATE, DATE, DATE, DATE]
# 9                                                    []
# 10                                      [LOC, LOC, LOC]
# 11                                                [ORG]
# 12                                   [TIME, TIME, TIME]
# 13                                            [ORDINAL]
# Name: Named Entities, dtype: object

# %% [markdown]
# Let's take a look at the named entities in the song called I Miss You.

# %%
# Extract the first Doc object
doc = songs_df2['Doc'][2]

# Visualize named entity tagging in a single paper
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I want every single piece of you I want your heaven and your oceans too Treat me soft but touch me cruel I wanna teach you things you never knew, baby Bring the floor up to my knees Let me fall into your gravity Then kiss me back to life to see Your body standing over me Baby, don't let the lights go down
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Baby
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , don't let the lights go down
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Baby
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , don't let the lights go down Lights go down, lights go down Lights go down, lights go down
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Down
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , down, down I miss you when the lights go out It illuminates all of my doubts Pull me in, hold me tight, don't let go Baby, give me light I miss you when the lights go out It illuminates all of my doubts Pull me in, hold me tight, don't let go Baby, give me light I love the way your body moves
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Towards
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  me from across the room Brushing past my every groove No one has me like you do, baby Bring your heart, I'll bring my soul But be delicate with my ego I wanna step into your great unknown With you and me setting the tone Baby, don't let the lights go down
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Baby
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , don't let the lights go down
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Baby
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , don't let the lights go down Lights go down, lights go down Lights go down, lights go down
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Down
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , down, down I miss you when the lights go out It illuminates all of my doubts Pull me in, hold me tight, don't let go Baby, give me light I miss you when the lights go out It illuminates all of my doubts Pull me in, hold me tight, don't let go Baby, give me light We play so dirty in the dark 'Cause we are living worlds apart It only makes it harder, baby It only makes it harder, baby Harder, baby, harder, baby I miss you when the lights go out It illuminates all of my doubts Pull me in, hold me tight, don't let go Baby, give me light I miss you when the lights go out It illuminates all of my doubts Pull me in, hold me tight, don't let go Baby, give me light I miss you, I miss you I miss you, I miss you I miss you, I miss you I miss you, I miss you</div></span>

# %% [markdown]
# # Download Enriched Dataset

# %% [markdown]
# Now we can combine songs_df1 (generated by web scraping) with songs_df2 and download it as a csv file.

# %%
final_songs_df=songs_df1.merge(songs_df2, on="Filename")
final_songs_df.to_csv('Adele_Album 25_Songs.csv')
